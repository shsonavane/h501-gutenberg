# %%
# !conda env list
# Out:
# # conda environments:
# #
# # *  -> active
# # + -> frozen
# base                     /opt/miniconda3
# constellations           /opt/miniconda3/envs/constellations
# h501-gutenberg       *   /opt/miniconda3/envs/h501-gutenberg
# simple-streamlit         /opt/miniconda3/envs/simple-streamlit

# %%
from tt_gutenberg.authors import load_merged_gutenberg_data, list_authors

df_merged = load_merged_gutenberg_data()
print(f"\nMerged dataset shape: {df_merged.shape}")
print(f"\nColumns: {df_merged.columns.tolist()}")
print(f"\nFirst few rows:")
df_merged.head()
# Out:
# Loading gutenberg_authors.csv...
# Authors shape: (26077, 7)
# Loading gutenberg_metadata.csv...
# Metadata shape: (79491, 8)
# Loading gutenberg_languages.csv...
# Languages shape: (76205, 3)
#
# Merging metadata + authors...
# After merging metadata + authors: (79491, 14)
#
# Merging with languages...
# Final merged shape: (79740, 16)
#
# Merged dataset shape: (79740, 16)
#
# Columns: ['gutenberg_id', 'title', 'author_metadata', 'gutenberg_author_id', 'language', 'gutenberg_bookshelf', 'rights', 'has_text', 'author_author', 'alias', 'birthdate', 'deathdate', 'wikipedia', 'aliases', 'language_lang', 'total_languages']
#
# First few rows:
#    gutenberg_id                                              title  \
# 0             1  The Declaration of Independence of the United ...
# 1             2  The United States Bill of Rights\r\nThe Ten Or...
# 2             3                John F. Kennedy's Inaugural Address
# 3             4  Lincoln's Gettysburg Address\r\nGiven November...
# ...
